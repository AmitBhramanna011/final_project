# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Handle table-like data and matrices
import numpy as np
import pandas as pd
import math 
# Modelling Algorithms
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Modelling Helpers
from sklearn.preprocessing import Imputer , Normalizer , scale
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV

# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Configure visualisations
# %matplotlib inline
mpl.style.use( 'ggplot' )
sns.set_style( 'white' )
pylab.rcParams[ 'figure.figsize' ] = 8 , 6
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 20
#      17 from sklearn.metrics import accuracy_score
#      19 # Modelling Helpers
# ---> 20 from sklearn.preprocessing import Imputer , Normalizer , scale
#      21 from sklearn.model_selection import train_test_split
#      22 from sklearn.feature_selection import RFECV
#
# ImportError: cannot import name 'Imputer' from 'sklearn.preprocessing' (C:\Users\amitb\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\preprocessing\__init__.py)

# %%
train = pd.read_csv("total.csv")
df = train

# %%
df.head()
# Out:
#     timestamp  state district     market               commodity  \
# 0  1523025126  Assam  Barpeta  Bohorihat  Black Gram (Urd Beans)
# 1  1523025126  Assam  Barpeta  Bohorihat         Corriander seed
# 2  1523025126  Assam  Barpeta  Bohorihat                    Jute
# 3  1523025126  Assam  Barpeta  Bohorihat           Lentil(Masur)
# 4  1523025126  Assam  Barpeta  Bohorihat                 Mustard
#
#               variety arrival_date  min_price  max_price  modal_price
# 0  Black Gram (Whole)   06/04/2018     2800.0     3000.0       2900.0
# 1      Coriander Seed   06/04/2018     3500.0     4000.0       3825.0
# 2                TD-5   06/04/2018     3200.0     3875.0       3825.0
# 3         Masoor Gola   06/04/2018     3400.0     3600.0       3500.0
# 4             Mustard   06/04/2018     3550.0     3650.0       3600.0

# %%
df.describe()
# Out:
#           timestamp     min_price      max_price    modal_price
# count  7.418000e+03   7418.000000    7418.000000    7418.000000
# mean   1.523025e+09   2551.547816    2999.163084    2804.140783
# std    4.987461e-01   3563.042575    4199.273121    3917.043677
# min    1.523025e+09      0.000000       0.000000       0.410000
# 25%    1.523025e+09    900.000000    1100.000000    1000.000000
# 50%    1.523025e+09   1650.000000    2000.000000    1828.500000
# 75%    1.523025e+09   3200.000000    3650.000000    3500.000000
# max    1.523025e+09  95000.000000  110000.000000  100000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7418 entries, 0 to 7417
# Data columns (total 10 columns):
# timestamp       7418 non-null int64
# state           7418 non-null object
# district        7418 non-null object
# market          7418 non-null object
# commodity       7418 non-null object
# variety         7418 non-null object
# arrival_date    7418 non-null object
# min_price       7418 non-null float64
# max_price       7418 non-null float64
# modal_price     7418 non-null float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 579.6+ KB

# %%
df.shape
# Out:
# (7418, 10)

# %%
df.columns
# Out:
# Index(['timestamp', 'state', 'district', 'market', 'commodity', 'variety',
#        'arrival_date', 'min_price', 'max_price', 'modal_price'],
#       dtype='object')

# %%
correlation_map = df[df.columns].corr()
obj = np.array(correlation_map)
obj[np.tril_indices_from(obj)] = False
fig,ax= plt.subplots()
fig.set_size_inches(15,10)
sns.heatmap(correlation_map, mask=obj,vmax=.7, square=True,annot=True)
fig.savefig("1.png")

# %%
df.state.unique()
# Out:
# array(['Assam', 'Chattisgarh', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra',
#        'Meghalaya', 'NCT of Delhi', 'Orissa', 'Pondicherry', 'Punjab',
#        'Rajasthan', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttrakhand', 'West Bengal'], dtype=object)

# %%
df.state.nunique()
# Out:
# 22

# %%
df.district.nunique()
# Out:
# 348

# %%
df.district.unique()
# Out:
# array(['Barpeta', 'Dhemaji', 'Kamrup', 'Nagaon', 'Nalbari', 'Sonitpur',
#        'Bastar', 'Bilaspur', 'Durg', 'Janjgir', 'Mahasamund',
#        'North Bastar', 'Rajnandgaon', 'Surguja', 'Ahmedabad', 'Amreli',
#        'Anand', 'Banaskanth', 'Bharuch', 'Bhavnagar', 'Dahod',
#        'Gandhinagar', 'Jamnagar', 'Junagarh', 'Kheda', 'Mehsana', 'Morbi',
#        'Panchmahals', 'Patan', 'Porbandar', 'Rajkot', 'Sabarkantha',
#        'Surat', 'Surendranagar', 'Vadodara(Baroda)', 'Valsad', 'Ambala',
#        'Bhiwani', 'Faridabad', 'Fatehabad', 'Jind', 'Kaithal', 'Karnal',
#        'Kurukshetra', 'Mahendragarh-Narnaul', 'Panchkula', 'Rohtak',
#        'Sirsa', 'Sonipat', 'Yamuna Nagar', 'Chamba', 'Hamirpur', 'Kangra',
#        'Kullu', 'Mandi', 'Shimla', 'Sirmore', 'Solan', 'Una', 'Bokaro',
#        'Dhanbad', 'East Singhbhum', 'Garhwa', 'Giridih', 'Godda', 'Gumla',
#        'Koderma', 'Lohardaga', 'Pakur', 'Ranchi', 'Simdega', 'Bagalkot',
#        'Bangalore', 'Belgaum', 'Bellary', 'Bidar', 'Bijapur',
#        'Chamrajnagar', 'Chikmagalur', 'Chitradurga', 'Davangere',
#        'Dharwad', 'Gadag', 'Gulbarga', 'Hassan', 'Haveri',
#        'Karwar(Uttar Kannad)', 'Kolar', 'Koppal', 'Madikeri(Kodagu)',
#        'Mandya', 'Mangalore(Dakshin Kannad)', 'Mysore', 'Raichur',
#        'Shimoga', 'Tumkur', 'Udupi', 'Alappuzha', 'Ernakulam', 'Idukki',
#        'Kannur', 'Kasargod', 'Kollam', 'Kottayam', 'Kozhikode(Calicut)',
#        'Malappuram', 'Palakad', 'Pathanamthitta', 'Thiruvananthapuram',
#        'Burhanpur', 'Chhindwara', 'Dewas', 'Dhar', 'Dindori', 'Harda',
#        'Hoshangabad', 'Indore', 'Khargone', 'Mandsaur', 'Neemuch', 'Panna',
#        'Rajgarh', 'Ratlam', 'Sagar', 'Satna', 'Sehore', 'Shajapur',
#        'Sheopur', 'Ujjain', 'Vidisha', 'Ahmednagar', 'Akola', 'Amarawati',
#        'Aurangabad', 'Beed', 'Bhandara', 'Buldhana', 'Chandrapur', 'Dhule',
#        'Gadchiroli', 'Hingoli', 'Jalana', 'Jalgaon', 'Kolhapur', 'Latur',
#        'Mumbai', 'Nagpur', 'Nanded', 'Nashik', 'Osmanabad', 'Parbhani',
#        'Pune', 'Raigad', 'Ratnagiri', 'Sangli', 'Satara', 'Sholapur',
#        'Thane', 'Wardha', 'Yavatmal', 'East Khasi Hills',
#        'West Garo Hills', 'West Jaintia Hills', 'Delhi', 'Bargarh',
#        'Bhadrak', 'Bolangir', 'Boudh', 'Cuttack', 'Deogarh', 'Dhenkanal',
#        'Ganjam', 'Jajpur', 'Kendrapara', 'Malkangiri', 'Mayurbhanja',
#        'Nayagarh', 'Nowarangpur', 'Nuapada', 'Sambalpur', 'Sonepur',
#        'Sundergarh', 'Karaikal', 'Amritsar', 'Barnala', 'Bhatinda',
#        'Faridkot', 'Fatehgarh', 'Fazilka', 'Ferozpur', 'Gurdaspur',
#        'Hoshiarpur', 'Jalandhar', 'kapurthala', 'Ludhiana', 'Moga',
#        'Mohali', 'Muktsar', 'Nawanshahr', 'Pathankot', 'Patiala',
#        'Ropar (Rupnagar)', 'Sangrur', 'Tarntaran', 'Ajmer', 'Banswara',
#        'Baran', 'Barmer', 'Bharatpur', 'Bikaner', 'Chittorgarh', 'Churu',
#        'Dausa', 'Ganganagar', 'Hanumangarh', 'Jaipur', 'Jalore',
#        'Jhalawar', 'Jodhpur', 'Kota', 'Pali', 'Sikar', 'Sirohi',
#        'Swai Madhopur', 'Tonk', 'Udaipur', 'Ariyalur', 'Coimbatore',
#        'Cuddalore', 'Dharmapuri', 'Dindigul', 'Erode', 'Kancheepuram',
#        'Krishnagiri', 'Madurai', 'Namakkal', 'Ramanathapuram', 'Salem',
#        'Sivaganga', 'Thanjavur', 'Theni', 'Thirunelveli',
#        'Thiruvannamalai', 'Thiruvarur', 'Vellore', 'Villupuram',
#        'Virudhunagar', 'Adilabad', 'Hyderabad', 'Karimnagar', 'Khammam',
#        'Mahbubnagar', 'Medak', 'Nalgonda', 'Nizamabad',
#        'Ranga Reddy Dist.', 'Warangal', 'Khowai', 'West District', 'Agra',
#        'Aligarh', 'Allahabad', 'Ambedkarnagar', 'Auraiya', 'Azamgarh',
#        'Badaun', 'Baghpat', 'Bahraich', 'Ballia', 'Balrampur', 'Banda',
#        'Barabanki', 'Bareilly', 'Basti', 'Bijnor', 'Bulandshahar',
#        'Chitrakut', 'Deoria', 'Etah', 'Etawah', 'Faizabad', 'Farukhabad',
#        'Fatehpur', 'Firozabad', 'Gautam Budh Nagar', 'Ghaziabad',
#        'Ghazipur', 'Gonda', 'Gorakhpur', 'Hardoi', 'Hathras',
#        'Jalaun (Orai)', 'Jaunpur', 'Jhansi', 'Jyotiba Phule Nagar',
#        'Kannuj', 'Kanpur', 'Khiri (Lakhimpur)', 'Lakhimpur', 'Lalitpur',
#        'Lucknow', 'Maharajganj', 'Mahoba', 'Mainpuri', 'Mathura',
#        'Mau(Maunathbhanjan)', 'Meerut', 'Mirzapur', 'Muradabad',
#        'Muzaffarnagar', 'Padrauna(Kusinagar)', 'Pillibhit', 'Pratapgarh',
#        'Raebarelli', 'Rampur', 'Saharanpur', 'Sant Kabir Nagar',
#        'Shahjahanpur', 'Shravasti', 'Siddharth Nagar', 'Sitapur',
#        'Sonbhadra', 'Sultanpur', 'Unnao', 'Varanasi', 'Champawat',
#        'Dehradoon', 'Garhwal (Pauri)', 'Haridwar', 'Nanital',
#        'UdhamSinghNagar', 'Bankura', 'Birbhum', 'Burdwan', 'Coochbehar',
#        'Dakshin Dinajpur', 'Darjeeling', 'Hooghly', 'Howrah', 'Jalpaiguri',
#        'Kolkata', 'Malda', 'Medinipur(E)', 'Medinipur(W)', 'Murshidabad',
#        'Nadia', 'Puruliya', 'Uttar Dinajpur'], dtype=object)

# %%
df.market.nunique()
# Out:
# 990

# %%
df.commodity.nunique()
# Out:
# 192

# %%
df.commodity.unique()
# Out:
# array(['Black Gram (Urd Beans)', 'Corriander seed', 'Jute',
#        'Lentil(Masur)', 'Mustard', 'Potato', 'Wheat Atta', 'Maida Atta',
#        'Green Chilli', 'Green Gram Dal (Moong Dal)', 'Paddy(Dhan)',
#        'Bengal Gram(Gram)', 'Lak(Teora)', 'Onion', 'Tomato', 'Tinda',
#        'Mahua', 'Bhindi(Ladies Finger)', 'Lemon', 'Maize', 'Bottle gourd',
#        'Brinjal', 'Carrot', 'Methi(Leaves)', 'Cotton',
#        'Bajra(Pearl Millet/Cumbu)', 'Castor Seed', 'Chili Red',
#        'Cummin Seed(Jeera)', 'Jowar(Sorghum)', 'Methi Seeds',
#        'Sesamum(Sesame,Gingelly,Til)', 'Wheat', 'Suva (Dill Seed)',
#        'Rajgir', 'Soanf', 'Guar Seed(Cluster Beans Seed)',
#        'Coriander(Leaves)', 'Ginger(Green)', 'Groundnut',
#        'Arhar (Tur/Red Gram)', 'Beans', 'Soyabean', 'Barley (Jau)',
#        'Green Gram (Moong)', 'Groundnut (Split)', 'Isabgul (Psyllium)',
#        'Kulthi(Horse Gram)', 'Ground Nut Seed', 'Garlic', 'Cluster beans',
#        'Cauliflower', 'Cucumbar(Kheera)', 'Pumpkin', 'Apple',
#        'Bitter gourd', 'Cabbage', 'Capsicum', 'Ginger(Dry)',
#        'Long Melon(Kakri)', 'Mango', 'Peas Wet', 'Raddish', 'Spinach',
#        'Banana', 'Ber(Zizyphus/Borehannu)', 'Grapes',
#        'Mousambi(Sweet Lime)', 'Turnip', 'Orange', 'Pine Apple',
#        'Pomegranate', 'Water Melon', 'Chikoos(Sapota)', 'Green Peas',
#        'Karbuja(Musk Melon)', 'Linseed', 'Sponge gourd', 'Kinnow',
#        'French Beans (Frasbean)', 'Guava', 'Papaya',
#        'Squash(Chappal Kadoo)', 'Gur(Jaggery)',
#        'Bengal Gram Dal (Chana Dal)', 'Masur Dal', 'Sugar',
#        'Pointed gourd (Parval)', 'Arhar Dal(Tur Dal)', 'Mustard Oil',
#        'Rice', 'Jack Fruit', 'Dalda', 'Peas(Dry)', 'Tamarind Fruit',
#        'Cowpea (Lobia/Karamani)', 'Sunflower', 'Alasande Gram',
#        'Avare Dal', 'Black Gram Dal (Urd Dal)', 'Black pepper',
#        'Cashewnuts', 'Chennangi Dal', 'Coconut', 'Dry Chillies',
#        'Moath Dal', 'Ragi (Finger Millet)', 'Ridgeguard(Tori)', 'Beetroot',
#        'Chilly Capsicum', 'Drumstick', 'Knool Khol', 'Seemebadnekai',
#        'Snakeguard', 'Foxtail Millet(Navane)', 'Safflower',
#        'Banana - Green', 'Tender Coconut', 'Lint', 'Sajje', 'Copra',
#        'Arecanut(Betelnut/Supari)', 'Chapparad Avare', 'Honge seed',
#        'T.V. Cumbu', 'Tamarind Seed', 'Soapnut(Antawala/Retha)',
#        'Elephant Yam (Suran)', 'Amphophalus', 'Ashgourd', 'Coconut Oil',
#        'Cowpea(Veg)', 'Gingelly Oil', 'Amaranthus', 'Colacasia', 'Tapioca',
#        'Little gourd (Kundru)', 'Mango (Raw-Ripe)', 'Cardamoms', 'Cloves',
#        'Coffee', 'Nutmeg', 'Rubber', 'Turmeric', 'Indian Beans (Seam)',
#        'Pepper ungarbled', 'Coconut Seed', 'Papaya (Raw)',
#        'Green Avare (W)', 'Kabuli Chana(Chickpeas-White)', 'Lime',
#        'Sweet Potato', 'Duster Beans', 'Myrobolan(Harad)', 'Plum',
#        'Mataki', 'Guar', 'Sweet Pumpkin', 'Mint(Pudina)', 'Onion Green',
#        'Leafy Vegetable', 'Betal Leaves', 'Field Pea', 'Chrysanthemum',
#        'Cornation', 'Gladiolus Cut Flower', 'Jaffri', 'Jarbara', 'Lilly',
#        'Marget', 'Marigold(Calcutta)', 'Marigold(loose)', 'Orchid',
#        'Patti Calcutta', 'Raibel', 'Rose(Local)', 'Rose(Loose)',
#        'Tube Rose(Double)', 'Tube Rose(Loose)', 'Tube Rose(Single)',
#        'Fish', 'Egg', 'Broken Rice', 'Round gourd', 'Peas cod',
#        'Gram Raw(Chholia)', 'Mashrooms', 'Yam', 'Wood', 'Pigs',
#        'White Peas', 'Firewood'], dtype=object)

# %%
df.variety.nunique()
# Out:
# 337

# %%
df.columns
# Out:
# Index(['timestamp', 'state', 'district', 'market', 'commodity', 'variety',
#        'arrival_date', 'min_price', 'max_price', 'modal_price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7418 entries, 0 to 7417
# Data columns (total 10 columns):
# timestamp       7418 non-null int64
# state           7418 non-null object
# district        7418 non-null object
# market          7418 non-null object
# commodity       7418 non-null object
# variety         7418 non-null object
# arrival_date    7418 non-null object
# min_price       7418 non-null float64
# max_price       7418 non-null float64
# modal_price     7418 non-null float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 579.6+ KB

# %%
df.info
# Out:
# <bound method DataFrame.info of        timestamp        state        district                  market  \
# 0     1523025126        Assam         Barpeta               Bohorihat
# 1     1523025126        Assam         Barpeta               Bohorihat
# 2     1523025126        Assam         Barpeta               Bohorihat
# 3     1523025126        Assam         Barpeta               Bohorihat
# 4     1523025126        Assam         Barpeta               Bohorihat
# 5     1523025126        Assam         Barpeta               Bohorihat
# 6     1523025126        Assam         Dhemaji              Silapathar
# 7     1523025126        Assam         Dhemaji              Silapathar
# 8     1523025126        Assam          Kamrup  P.O. Uparhali Guwahati
# 9     1523025126        Assam          Kamrup  P.O. Uparhali Guwahati
# 10    1523025126        Assam          Kamrup  P.O. Uparhali Guwahati
# 11    1523025126        Assam          Nagaon                   Dhing
# 12    1523025126        Assam          Nagaon                   Dhing
# 13    1523025126        Assam          Nagaon                   Dhing
# 14    1523025126        Assam          Nagaon                   Dhing
# 15    1523025126        Assam          Nagaon                   Dhing
# 16    1523025126        Assam         Nalbari                 Nalbari
# 17    1523025126        Assam         Nalbari                 Nalbari
# 18    1523025126        Assam         Nalbari                 Nalbari
# 19    1523025126        Assam         Nalbari                 Nalbari
# 20    1523025126        Assam        Sonitpur              Dhekiajuli
# 21    1523025126  Chattisgarh          Bastar                 Charama
# 22    1523025126  Chattisgarh        Bilaspur               Takhatpur
# 23    1523025126  Chattisgarh        Bilaspur               Takhatpur
# 24    1523025126  Chattisgarh        Bilaspur                  Tiphra
# 25    1523025126  Chattisgarh        Bilaspur                  Tiphra
# 26    1523025126  Chattisgarh        Bilaspur                  Tiphra
# 27    1523025126  Chattisgarh            Durg                    Durg
# 28    1523025126  Chattisgarh         Janjgir                Akaltara
# 29    1523025126  Chattisgarh         Janjgir                 Amadula
# ...          ...          ...             ...                     ...
# 7388  1523025127  West Bengal           Nadia                 Kalyani
# 7389  1523025127  West Bengal           Nadia                 Kalyani
# 7390  1523025127  West Bengal           Nadia                 Kalyani
# 7391  1523025127  West Bengal           Nadia                Ranaghat
# 7392  1523025127  West Bengal           Nadia                Ranaghat
# 7393  1523025127  West Bengal           Nadia                Ranaghat
# 7394  1523025127  West Bengal           Nadia                Ranaghat
# 7395  1523025127  West Bengal           Nadia                Ranaghat
# 7396  1523025127  West Bengal           Nadia                Ranaghat
# 7397  1523025127  West Bengal           Nadia                Ranaghat
# 7398  1523025127  West Bengal           Nadia                Ranaghat
# 7399  1523025127  West Bengal        Puruliya              Balarampur
# 7400  1523025127  West Bengal        Puruliya              Balarampur
# 7401  1523025127  West Bengal        Puruliya              Balarampur
# 7402  1523025127  West Bengal        Puruliya              Balarampur
# 7403  1523025127  West Bengal        Puruliya              Balarampur
# 7404  1523025127  West Bengal        Puruliya              Balarampur
# 7405  1523025127  West Bengal        Puruliya              Balarampur
# 7406  1523025127  West Bengal        Puruliya                 Purulia
# 7407  1523025127  West Bengal        Puruliya                 Purulia
# 7408  1523025127  West Bengal        Puruliya                 Purulia
# 7409  1523025127  West Bengal        Puruliya                 Purulia
# 7410  1523025127  West Bengal        Puruliya                 Purulia
# 7411  1523025127  West Bengal        Puruliya                 Purulia
# 7412  1523025127  West Bengal        Puruliya                 Purulia
# 7413  1523025127  West Bengal  Uttar Dinajpur                Islampur
# 7414  1523025127  West Bengal  Uttar Dinajpur                Islampur
# 7415  1523025127  West Bengal  Uttar Dinajpur                Islampur
# 7416  1523025127  West Bengal  Uttar Dinajpur                 Raiganj
# 7417  1523025127  West Bengal  Uttar Dinajpur                 Raiganj
#
#                        commodity             variety arrival_date  min_price  \
# 0         Black Gram (Urd Beans)  Black Gram (Whole)   06/04/2018     2800.0
# 1                Corriander seed      Coriander Seed   06/04/2018     3500.0
# 2                           Jute                TD-5   06/04/2018     3200.0
# 3                  Lentil(Masur)         Masoor Gola   06/04/2018     3400.0
# 4                        Mustard             Mustard   06/04/2018     3550.0
# 5                         Potato              Potato   06/04/2018      775.0
# 6                  Lentil(Masur)           Masur Dal   06/04/2018     5500.0
# 7                     Wheat Atta          Wheat Atta   06/04/2018     2400.0
# 8                     Maida Atta          Maida Atta   06/04/2018     2360.0
# 9                         Potato              Potato   06/04/2018     1100.0
# 10                    Wheat Atta          Wheat Atta   06/04/2018     2300.0
# 11                  Green Chilli        Green Chilly   06/04/2018     1500.0
# 12                          Jute                TD-5   06/04/2018     3000.0
# 13                    Maida Atta          Maida Atta   06/04/2018     2250.0
# 14                       Mustard             Mustard   06/04/2018     3500.0
# 15                    Wheat Atta          Wheat Atta   06/04/2018     2120.0
# 16    Green Gram Dal (Moong Dal)      Green Gram Dal   06/04/2018     6200.0
# 17                 Lentil(Masur)           Masur Dal   06/04/2018     4600.0
# 18                    Maida Atta          Maida Atta   06/04/2018     2400.0
# 19                    Wheat Atta          Wheat Atta   06/04/2018     2300.0
# 20                          Jute                TD-5   06/04/2018     3600.0
# 21                   Paddy(Dhan)               Other   06/04/2018     1500.0
# 22             Bengal Gram(Gram)        Desi (Whole)   06/04/2018     3500.0
# 23                    Lak(Teora)         Lak (Whole)   06/04/2018     1500.0
# 24                         Onion               Other   06/04/2018     1100.0
# 25                        Potato               Other   06/04/2018     1100.0
# 26                        Tomato               Other   06/04/2018      200.0
# 27                         Tinda               Other   06/04/2018     2000.0
# 28                   Paddy(Dhan)        Paddy Medium   06/04/2018     1615.0
# 29                   Paddy(Dhan)        Paddy Coarse   06/04/2018     1500.0
# ...                          ...                 ...          ...        ...
# 7388                        Rice               Other   06/04/2018     2700.0
# 7389                        Rice                Sona   06/04/2018     2200.0
# 7390               Sweet Pumpkin       Sweet Pumpkin   06/04/2018     1000.0
# 7391                     Brinjal               Other   06/04/2018     3300.0
# 7392                     Cabbage               Other   06/04/2018      410.0
# 7393                Green Chilli               Other   06/04/2018     2900.0
# 7394                       Onion               Other   06/04/2018      720.0
# 7395                      Potato               Jyoti   06/04/2018     1020.0
# 7396                     Pumpkin               Other   06/04/2018      720.0
# 7397                        Rice               Other   06/04/2018     3900.0
# 7398                      Tomato               Other   06/04/2018      410.0
# 7399       Bhindi(Ladies Finger)               Other   06/04/2018     2600.0
# 7400                     Brinjal               Other   06/04/2018     1000.0
# 7401                       Onion               Other   06/04/2018      950.0
# 7402                      Potato               Other   06/04/2018      820.0
# 7403                        Rice               Other   06/04/2018     2620.0
# 7404            Ridgeguard(Tori)               Other   06/04/2018     2000.0
# 7405                      Tomato               Other   06/04/2018      250.0
# 7406                     Brinjal               Other   06/04/2018     1700.0
# 7407                   Masur Dal           Masur Dal   06/04/2018     5900.0
# 7408                       Onion               Other   06/04/2018      800.0
# 7409                      Potato               Jyoti   06/04/2018      880.0
# 7410                     Pumpkin               Other   06/04/2018     1000.0
# 7411                        Rice               Other   06/04/2018     2800.0
# 7412                      Tomato               Other   06/04/2018      650.0
# 7413                        Jute                TD-5   06/04/2018     3700.0
# 7414                      Potato               Jyoti   06/04/2018      830.0
# 7415                        Rice               Other   06/04/2018     3250.0
# 7416                        Jute                TD-5   06/04/2018     3600.0
# 7417                        Rice               Other   06/04/2018     3150.0
#
#       max_price  modal_price
# 0        3000.0       2900.0
# 1        4000.0       3825.0
# 2        3875.0       3825.0
# 3        3600.0       3500.0
# 4        3650.0       3600.0
# 5         850.0        800.0
# 6        6000.0       5700.0
# 7        2600.0       2500.0
# 8        2400.0       2380.0
# 9        1180.0       1140.0
# 10       2360.0       2330.0
# 11       2000.0       1800.0
# 12       3500.0       3400.0
# 13       2460.0       2270.0
# 14       4000.0       3800.0
# 15       2320.0       2230.0
# 16       7000.0       6600.0
# 17       4800.0       4700.0
# 18       2600.0       2500.0
# 19       2500.0       2400.0
# 20       3900.0       3900.0
# 21       1500.0       1500.0
# 22       3500.0       3500.0
# 23       1580.0       1550.0
# 24       1300.0       1200.0
# 25       1300.0       1200.0
# 26        300.0        250.0
# 27       2500.0       2250.0
# 28       1615.0       1615.0
# 29       1500.0       1500.0
# ...         ...          ...
# 7388     3100.0       3000.0
# 7389     2500.0       2400.0
# 7390     1200.0       1100.0
# 7391     3450.0       3400.0
# 7392      480.0        450.0
# 7393     3050.0       3000.0
# 7394      780.0        750.0
# 7395     1040.0       1040.0
# 7396      780.0        750.0
# 7397     4000.0       3920.0
# 7398      480.0        450.0
# 7399     2800.0       2700.0
# 7400     1200.0       1100.0
# 7401     1350.0       1200.0
# 7402      860.0        840.0
# 7403     2660.0       2640.0
# 7404     2200.0       2100.0
# 7405      350.0        300.0
# 7406     2000.0       1900.0
# 7407     6000.0       5900.0
# 7408     1100.0        900.0
# 7409      900.0        880.0
# 7410     1200.0       1000.0
# 7411     2840.0       2800.0
# 7412      750.0        750.0
# 7413     3900.0       3800.0
# 7414      870.0        850.0
# 7415     3350.0       3300.0
# 7416     3800.0       3700.0
# 7417     3250.0       3200.0
#
# [7418 rows x 10 columns]>

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
newdf = df.select_dtypes(include=numerics)       #  numeric dataframe
objects = ['O']
df_o = df.select_dtypes(include=objects)

# %%
newdf.columns               #  numeric columns
# Out:
# Index(['timestamp', 'min_price', 'max_price', 'modal_price'], dtype='object')

# %%
df_o.columns                 #  categorical columns
# Out:
# Index(['state', 'district', 'market', 'commodity', 'variety', 'arrival_date'], dtype='object')

# %%
df.state.value_counts()
# Out:
# Uttar Pradesh       2343
# Kerala               970
# Maharashtra          676
# Punjab               599
# Karnataka            421
# Gujarat              342
# West Bengal          302
# Haryana              279
# Orissa               257
# Telangana            245
# Himachal Pradesh     239
# Tamil Nadu           184
# Jharkhand            130
# Madhya Pradesh       123
# Rajasthan            104
# Uttrakhand            71
# NCT of Delhi          36
# Tripura               33
# Chattisgarh           23
# Assam                 21
# Meghalaya             12
# Pondicherry            8
# Name: state, dtype: int64

# %%
df.district.value_counts()
# Out:
# Agra                  139
# Kottayam              137
# Palakad               136
# Ernakulam             124
# Alappuzha             120
# Aligarh                98
# Thiruvananthapuram     95
# Kozhikode(Calicut)     94
# Hamirpur               91
# Jalandhar              87
# Hyderabad              86
# Malappuram             83
# Kollam                 81
# Bangalore              79
# Bulandshahar           78
# Pune                   77
# Sholapur               71
# Muzaffarnagar          70
# Firozabad              68
# Muktsar                66
# Kanpur                 65
# Jalgaon                64
# Ahmednagar             63
# Pillibhit              62
# Shahjahanpur           61
# Etawah                 61
# Gurdaspur              59
# Idukki                 59
# Mainpuri               58
# Saharanpur             55
#                      ...
# Ghazipur                2
# Kancheepuram            2
# West Garo Hills         2
# Dhemaji                 2
# Panchmahals             2
# Surguja                 2
# Raichur                 2
# Sirohi                  2
# Jalore                  1
# Belgaum                 1
# Banswara                1
# Champawat               1
# Bastar                  1
# Shravasti               1
# Ramanathapuram          1
# Valsad                  1
# Shimla                  1
# Sagar                   1
# Churu                   1
# Satna                   1
# Jaipur                  1
# Virudhunagar            1
# Udaipur                 1
# Koppal                  1
# Raigad                  1
# Sonitpur                1
# Cuddalore               1
# Sivaganga               1
# Durg                    1
# West District           1
# Name: district, Length: 348, dtype: int64

# %%
df.commodity.value_counts()
# Out:
# Potato                       383
# Onion                        353
# Tomato                       340
# Brinjal                      312
# Wheat                        281
# Paddy(Dhan)                  244
# Green Chilli                 243
# Cauliflower                  205
# Rice                         193
# Cabbage                      176
# Bottle gourd                 169
# Pumpkin                      166
# Banana                       162
# Mustard                      162
# Bhindi(Ladies Finger)        155
# Bengal Gram(Gram)            153
# Cucumbar(Kheera)             151
# Carrot                       127
# Apple                        121
# Maize                        121
# Raddish                      118
# Gur(Jaggery)                 114
# Bitter gourd                 112
# Ginger(Green)                103
# Cotton                        95
# Bajra(Pearl Millet/Cumbu)     85
# Garlic                        80
# Arhar (Tur/Red Gram)          76
# Grapes                        76
# Banana - Green                68
#                             ...
# Lak(Teora)                     1
# Chrysanthemum                  1
# Tube Rose(Double)              1
# Plum                           1
# Foxtail Millet(Navane)         1
# Chennangi Dal                  1
# Jaffri                         1
# Rose(Local)                    1
# Lilly                          1
# Mashrooms                      1
# Gingelly Oil                   1
# Tube Rose(Loose)               1
# Sajje                          1
# Seemebadnekai                  1
# Moath Dal                      1
# Myrobolan(Harad)               1
# Egg                            1
# Jarbara                        1
# Marigold(loose)                1
# Coffee                         1
# Cornation                      1
# Mataki                         1
# Pigs                           1
# Turnip                         1
# Broken Rice                    1
# Raibel                         1
# Marget                         1
# Honge seed                     1
# Yam                            1
# Cloves                         1
# Name: commodity, Length: 192, dtype: int64

# %%
pd.crosstab([df.state], [df.commodity], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col0 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col1 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col2 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col3 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col4 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col5 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col6 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col7 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col8 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col9 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col10 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col11 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col12 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col13 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col14 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col15 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col16 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col17 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col18 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col19 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col20 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col21 {
#             background-color:  #fffb00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col22 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col23 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col24 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col25 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col26 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col27 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col28 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col29 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col30 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col31 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col32 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col33 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col34 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col35 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col36 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col37 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col38 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col39 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col40 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col41 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col42 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col43 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col44 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col45 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col46 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col47 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col48 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col49 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col50 {
#             background-color:  #ffef00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col51 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col52 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col53 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col54 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col55 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col56 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col57 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col58 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col59 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col60 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col61 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col62 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col63 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col64 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col65 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col66 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col67 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col68 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col69 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col70 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col71 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col72 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col73 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col74 {
#             background-color:  #ffff00;
#         }    #T_cbfc040c_3af1_11e8_8640_d9c40bac4e62row0_col75 {
#             background-color:  #fffe00;
#         }

# %%
gp = df.loc[(df.state == "Rajasthan") & (df.district == "Ajmer") , : ]

# %%
a = ""
for i in range(0 , gp.shape[0]):
    a = a + gp.commodity + "    " + gp.variety + "    " + gp.arrival_date + "    " + str(gp.min_price) + "    " + str(gp.max_price) + "    " + str(gp.modal_price) + "    "

# %%
a
# Out:
# 4136    Bajra(Pearl Millet/Cumbu)    Other    06/04/20...
# 4137    Barley (Jau)    Other    06/04/2018    4136   ...
# 4138    Guar    Other    06/04/2018    4136    1100.0\...
# 4139    Mustard    Other    06/04/2018    4136    1100...
# 4140    Barley (Jau)    Other    06/04/2018    4136   ...
# 4141    Bengal Gram(Gram)    Other    06/04/2018    41...
# 4142    Cotton    American    06/04/2018    4136    11...
# 4143    Mustard    Other    06/04/2018    4136    1100...
# 4144    Wheat    Other    06/04/2018    4136    1100.0...
# dtype: object

# %%
gp
# Out:
#        timestamp      state district       market                  commodity  \
# 4136  1523025127  Rajasthan    Ajmer       Beawar  Bajra(Pearl Millet/Cumbu)
# 4137  1523025127  Rajasthan    Ajmer       Beawar               Barley (Jau)
# 4138  1523025127  Rajasthan    Ajmer       Beawar                       Guar
# 4139  1523025127  Rajasthan    Ajmer       Beawar                    Mustard
# 4140  1523025127  Rajasthan    Ajmer  Bijay Nagar               Barley (Jau)
# 4141  1523025127  Rajasthan    Ajmer  Bijay Nagar          Bengal Gram(Gram)
# 4142  1523025127  Rajasthan    Ajmer  Bijay Nagar                     Cotton
# 4143  1523025127  Rajasthan    Ajmer  Bijay Nagar                    Mustard
# 4144  1523025127  Rajasthan    Ajmer  Bijay Nagar                      Wheat
#
#        variety arrival_date  min_price  max_price  modal_price
# 4136     Other   06/04/2018     1100.0     1200.0       1150.0
# 4137     Other   06/04/2018     1300.0     1350.0       1325.0
# 4138     Other   06/04/2018     3700.0     3850.0       3775.0
# 4139     Other   06/04/2018     3400.0     3550.0       3475.0
# 4140     Other   06/04/2018     1281.0     1300.0       1290.0
# 4141     Other   06/04/2018     2602.0     3550.0       3500.0
# 4142  American   06/04/2018     4856.0     5150.0       5000.0
# 4143     Other   06/04/2018     3375.0     3452.0       3400.0
# 4144     Other   06/04/2018     1250.0     1800.0       1700.0

# %%
def get_graphs(state , district , market):
    gp = df.loc[(df.state == state) & (df.district == district) & (df.market == market), : ]
    fig, axes = plt.subplots(5,1)
    fig.set_size_inches(20, 30)
    sns.barplot(data=gp ,y="modal_price",x="commodity", hue = "variety" ,orient="v" ,ax=axes[0] )
    sns.kdeplot(gp.modal_price , shade=True, color="r" , ax=axes[1] )
    sns.stripplot(x="commodity", y="modal_price", data=gp , hue = "variety" , jitter=True , ax = axes[2])
    sns.distplot(gp.modal_price , ax = axes[3])
    sns.pointplot(x="commodity", y="modal_price", data=gp , ax = axes[4] ) 
    fig.savefig("2.png")

# %%
get_graphs("Kerala" , "Alappuzha" , "Aroor")

# %%
 def pairplot(state , district , market):
    gp = df.loc[(df.state == state) & (df.district == district) & (df.market == market), : ]
    g = sns.PairGrid(gp , hue = "variety")
    g = g.map_diag(plt.hist)
    g = g.map_offdiag(plt.scatter)
    g = g.add_legend()
    g = plt.figure(figsize=(15,10))
    fig.savefig("4.png")

# %%
pairplot("Uttar Pradesh" , "Agra" , "Achnera")

# %%
sns.pairplot(gp , hue = "variety")

# %%
sns.jointplot(x="min_price", y="modal_price", data=gp , kind="reg")

# %%
g = sns.jointplot(x="max_price", y="modal_price", data=gp , kind="reg")

# %%
g = sns.jointplot(x="min_price", y="max_price", data=gp , kind="reg")

# %%
temp = df.loc[(df.state == "Uttar Pradesh") & (df.district == "Agra") & (df.commodity == "Potato"), : ]
temp
# Out:
#        timestamp          state district          market commodity variety  \
# 4718  1523025127  Uttar Pradesh     Agra         Achnera    Potato    Desi
# 4752  1523025127  Uttar Pradesh     Agra            Agra    Potato    Desi
# 4771  1523025127  Uttar Pradesh     Agra  Fatehpur Sikri    Potato   Local
# 4791  1523025127  Uttar Pradesh     Agra         Jagnair    Potato    Desi
# 4811  1523025127  Uttar Pradesh     Agra           Jarar    Potato    Desi
# 4835  1523025127  Uttar Pradesh     Agra      Khairagarh    Potato    Desi
#
#      arrival_date  min_price  max_price  modal_price
# 4718   06/04/2018      840.0      860.0        850.0
# 4752   06/04/2018      850.0      980.0        910.0
# 4771   06/04/2018      800.0      940.0        870.0
# 4791   06/04/2018      840.0      860.0        850.0
# 4811   06/04/2018      600.0      800.0        700.0
# 4835   06/04/2018      840.0      860.0        850.0

# %%
def get_val(state , district , commodity):
    temp = df.loc[(df.state == state) & (df.district == district) & (df.commodity == commodity), : ]
    fig, axes = plt.subplots(6,1)
    fig.set_size_inches(20, 30)
    sns.barplot(data=temp ,y="min_price",x="market" ,orient="v" , ax = axes[0] )
    sns.pointplot(data=temp ,y="min_price",x="market" ,orient="v" , ax = axes[1] )
    #sns.stripplot(x="market", y="min_price", data=temp , jitter=True ,  ax = axes[1])
    #sns.distplot(temp.modal_price , ax = axes[3])
    sns.barplot(data=temp ,y="modal_price",x="market" ,orient="v" , ax = axes[2] )
    sns.pointplot(data=temp ,y="modal_price",x="market" ,orient="v" , ax = axes[3] )
    sns.barplot(data=temp ,y="max_price",x="market" ,orient="v" , ax = axes[4] )
    sns.pointplot(data=temp ,y="max_price",x="market" ,orient="v" , ax = axes[5] )
    fig.savefig("3.png")

# %%
get_val("Uttar Pradesh" , "Agra" , "Brinjal")

# %%
df.head()
# Out:
#     timestamp  state district     market               commodity  \
# 0  1523025126  Assam  Barpeta  Bohorihat  Black Gram (Urd Beans)
# 1  1523025126  Assam  Barpeta  Bohorihat         Corriander seed
# 2  1523025126  Assam  Barpeta  Bohorihat                    Jute
# 3  1523025126  Assam  Barpeta  Bohorihat           Lentil(Masur)
# 4  1523025126  Assam  Barpeta  Bohorihat                 Mustard
#
#               variety arrival_date  min_price  max_price  modal_price
# 0  Black Gram (Whole)   06/04/2018     2800.0     3000.0       2900.0
# 1      Coriander Seed   06/04/2018     3500.0     4000.0       3825.0
# 2                TD-5   06/04/2018     3200.0     3875.0       3825.0
# 3         Masoor Gola   06/04/2018     3400.0     3600.0       3500.0
# 4             Mustard   06/04/2018     3550.0     3650.0       3600.0

# %%
df.groupby( ['state' , 'commodity'] ).mean()
# Out:
#                                            timestamp    min_price  \
# state       commodity
# Assam       Black Gram (Urd Beans)      1.523025e+09  2800.000000
#             Corriander seed             1.523025e+09  3500.000000
#             Green Chilli                1.523025e+09  1500.000000
#             Green Gram Dal (Moong Dal)  1.523025e+09  6200.000000
#             Jute                        1.523025e+09  3266.666667
#             Lentil(Masur)               1.523025e+09  4500.000000
#             Maida Atta                  1.523025e+09  2336.666667
#             Mustard                     1.523025e+09  3525.000000
#             Potato                      1.523025e+09   937.500000
#             Wheat Atta                  1.523025e+09  2280.000000
# Chattisgarh Bengal Gram(Gram)           1.523025e+09  3500.000000
#             Bhindi(Ladies Finger)       1.523025e+09  1000.000000
#             Lak(Teora)                  1.523025e+09  1500.000000
#             Lemon                       1.523025e+09  5400.000000
#             Mahua                       1.523025e+09  2433.333333
#             Maize                       1.523025e+09  1430.000000
#             Onion                       1.523025e+09  1100.000000
#             Paddy(Dhan)                 1.523025e+09  1517.100000
#             Potato                      1.523025e+09  1100.000000
#             Tinda                       1.523025e+09  2000.000000
#             Tomato                      1.523025e+09   200.000000
# Gujarat     Arhar (Tur/Red Gram)        1.523025e+09  3550.000000
#             Bajra(Pearl Millet/Cumbu)   1.523025e+09  1069.500000
#             Barley (Jau)                1.523025e+09  1382.500000
#             Beans                       1.523025e+09  4000.000000
#             Bengal Gram(Gram)           1.523025e+09  3433.333333
#             Black Gram (Urd Beans)      1.523025e+09  2424.166667
#             Bottle gourd                1.523025e+09   464.583333
#             Brinjal                     1.523025e+09   440.000000
#             Carrot                      1.523025e+09   866.666667
# ...                                              ...          ...
# Uttrakhand  Papaya                      1.523025e+09  1000.000000
#             Potato                      1.523025e+09   470.909091
#             Pumpkin                     1.523025e+09   433.333333
#             Raddish                     1.523025e+09   200.000000
#             Tomato                      1.523025e+09   608.750000
# West Bengal Bhindi(Ladies Finger)       1.523025e+09  2720.000000
#             Bitter gourd                1.523025e+09  2580.000000
#             Black Gram (Urd Beans)      1.523025e+09  5166.666667
#             Brinjal                     1.523025e+09  1617.307692
#             Cabbage                     1.523025e+09   432.857143
#             Cucumbar(Kheera)            1.523025e+09  1116.666667
#             Ginger(Dry)                 1.523025e+09  4100.000000
#             Green Chilli                1.523025e+09  2889.583333
#             Green Gram (Moong)          1.523025e+09  7200.000000
#             Jute                        1.523025e+09  3496.153846
#             Lentil(Masur)               1.523025e+09  6100.000000
#             Masur Dal                   1.523025e+09  6033.333333
#             Mustard                     1.523025e+09  3557.692308
#             Mustard Oil                 1.523025e+09  9200.000000
#             Onion                       1.523025e+09  1020.625000
#             Paddy(Dhan)                 1.523025e+09  1602.458333
#             Pointed gourd (Parval)      1.523025e+09  3060.000000
#             Potato                      1.523025e+09   903.452381
#             Pumpkin                     1.523025e+09   860.000000
#             Rice                        1.523025e+09  2814.615385
#             Ridgeguard(Tori)            1.523025e+09  2500.000000
#             Sugar                       1.523025e+09  3700.000000
#             Sweet Pumpkin               1.523025e+09   842.857143
#             Tomato                      1.523025e+09   633.888889
#             Wheat                       1.523025e+09  1626.250000
#
#                                           max_price  modal_price
# state       commodity
# Assam       Black Gram (Urd Beans)      3000.000000  2900.000000
#             Corriander seed             4000.000000  3825.000000
#             Green Chilli                2000.000000  1800.000000
#             Green Gram Dal (Moong Dal)  7000.000000  6600.000000
#             Jute                        3758.333333  3708.333333
#             Lentil(Masur)               4800.000000  4633.333333
#             Maida Atta                  2486.666667  2383.333333
#             Mustard                     3825.000000  3700.000000
#             Potato                      1015.000000   970.000000
#             Wheat Atta                  2445.000000  2365.000000
# Chattisgarh Bengal Gram(Gram)           3500.000000  3500.000000
#             Bhindi(Ladies Finger)       1000.000000  1000.000000
#             Lak(Teora)                  1580.000000  1550.000000
#             Lemon                       5400.000000  5400.000000
#             Mahua                       2433.333333  2433.333333
#             Maize                       1430.000000  1430.000000
#             Onion                       1300.000000  1200.000000
#             Paddy(Dhan)                 1518.000000  1517.500000
#             Potato                      1300.000000  1200.000000
#             Tinda                       2500.000000  2250.000000
#             Tomato                       250.000000   225.000000
# Gujarat     Arhar (Tur/Red Gram)        4191.666667  3991.666667
#             Bajra(Pearl Millet/Cumbu)   1283.750000  1212.850000
#             Barley (Jau)                1405.000000  1382.500000
#             Beans                       4700.000000  4600.000000
#             Bengal Gram(Gram)           3585.000000  3498.333333
#             Black Gram (Urd Beans)      3410.833333  3077.083333
#             Bottle gourd                 793.750000   629.166667
#             Brinjal                      845.000000   645.000000
#             Carrot                      1233.333333  1066.666667
# ...                                             ...          ...
# Uttrakhand  Papaya                      1050.000000  1025.000000
#             Potato                       640.909091   551.818182
#             Pumpkin                      595.000000   516.666667
#             Raddish                      315.000000   287.500000
#             Tomato                       788.750000   720.000000
# West Bengal Bhindi(Ladies Finger)       2920.000000  2840.000000
#             Bitter gourd                2800.000000  2720.000000
#             Black Gram (Urd Beans)      5333.333333  5250.000000
#             Brinjal                     1867.307692  1746.153846
#             Cabbage                      559.285714   500.000000
#             Cucumbar(Kheera)            1316.666667  1233.333333
#             Ginger(Dry)                 4300.000000  4200.000000
#             Green Chilli                3364.583333  3093.750000
#             Green Gram (Moong)          7400.000000  7300.000000
#             Jute                        3684.615385  3592.307692
#             Lentil(Masur)               6533.333333  6333.333333
#             Masur Dal                   6333.333333  6166.666667
#             Mustard                     3703.846154  3630.769231
#             Mustard Oil                 9260.000000  9250.000000
#             Onion                       1239.791667  1138.541667
#             Paddy(Dhan)                 1654.208333  1631.458333
#             Pointed gourd (Parval)      3300.000000  3200.000000
#             Potato                       962.261905   933.809524
#             Pumpkin                      990.000000   875.000000
#             Rice                        2960.000000  2894.326923
#             Ridgeguard(Tori)            2725.000000  2625.000000
#             Sugar                       3750.000000  3720.000000
#             Sweet Pumpkin               1042.857143   942.857143
#             Tomato                       818.333333   725.000000
#             Wheat                       1695.000000  1658.750000
#
# [820 rows x 4 columns]
